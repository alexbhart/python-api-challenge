# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    belaya gora  68.5333  146.4167    -44.41       100          89
# 1        1           lebu -37.6167  -73.6500     13.87        95           4
# 2        2  srednekolymsk  67.4500  153.6833    -34.92        96         100
# 3        3     morant bay  17.8815  -76.4093     25.79        80          25
# 4        4         dikson  73.5069   80.5464    -24.00        91         100
#
#    Wind Speed Country        Date
# 0        0.74      RU  1674448429
# 1        3.81      CL  1674448430
# 2        2.19      RU  1674448430
# 3        5.48      JM  1674448431
# 4       10.38      RU  1674448390

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_map = city_data_df.hvplot.points('Lng', 
                                           'Lat',
                                           geo = True,
                                           tiles = 'EsriNatGeo',
                                           size = "Humidity",
                                           scale = 1, 
                                           color = "City",
                                           alpha = 0.7
                                          )

# Display the map
city_data_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#clouds less than 45
#temp between 23 and 26
#humidity less than 60
#wind speed less than 3

city_data_vacay = city_data_df.loc[city_data_df['Max Temp'] >= 23]
city_data_vacay = city_data_vacay.loc[city_data_vacay['Max Temp'] < 26]
city_data_vacay = city_data_vacay.loc[city_data_vacay['Humidity'] < 75]
# city_data_vacay = city_data_vacay.loc[city_data_vacay['Cloudiness'] < 45]



# Drop any rows with null values
city_data_vacay.dropna()

# Display sample data
city_data_vacay
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 26        26         hobart -42.8794  147.3294     24.04        65
# 42        42    new norfolk -42.7826  147.0587     23.84        48
# 58        58      chuncheng  22.1731  111.7886     23.92        59
# 81        81     the valley  18.2170  -63.0578     25.61        74
# 83        83      nagothana  18.5333   73.1333     25.53        39
# 85        85        parakou   9.3372    2.6303     23.47        23
# 105      105      esperance -33.8667  121.9000     24.91        54
# 119      119        qandala  11.4720   49.8728     23.79        57
# 241      241        kahului  20.8947 -156.4700     25.01        73
# 242      242          zabid  14.1951   43.3152     23.58        65
# 249      249     pedernales  18.0384  -71.7440     23.33        49
# 271      271         faanui -16.4833 -151.7500     25.49        74
# 331      331     wollongong -34.4333  150.8833     24.49        65
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_vacay[['City', 'Lat', 'Lng', 'Humidity', 'Country']]
# hotel_df.head()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""
hotel_df.head()

# Display sample data
hotel_df
# Out:
# C:\Users\alexh\AppData\Local\Temp\ipykernel_9932\1312105492.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ""
#               City      Lat       Lng  Humidity Country Hotel Name
# 26          hobart -42.8794  147.3294        65      AU
# 42     new norfolk -42.7826  147.0587        48      AU
# 58       chuncheng  22.1731  111.7886        59      CN
# 81      the valley  18.2170  -63.0578        74      AI
# 83       nagothana  18.5333   73.1333        39      IN
# 85         parakou   9.3372    2.6303        23      BJ
# 105      esperance -33.8667  121.9000        54      AU
# 119        qandala  11.4720   49.8728        57      SO
# 241        kahului  20.8947 -156.4700        73      US
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# # Set parameters to search for a hotel
# radius = 10000
# params = {
#     "categories": "accommodation",
#     "conditions": "dogs.yes",
#     "apiKey": geoapify_key
# }

# # Print a message to follow up the hotel search
# print("Starting hotel search")

# # Iterate through the hotel_df DataFrame
# # for index, row in hotel_df.iterrows():
# # get latitude, longitude from the DataFrame
# hotel_lat = hotel_df['Lat'][row]
# hotel_lng = hotel_df['Lng'][row]


# # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
# params["filter"] = f"circle:{hotel_lng},{hotel_lat},{radius}"
# params["bias"] = f"proximity:{hotel_lng}, {hotel_lat}"

# # Set base URL
# base_url = "https://api.geoapify.com/v2/places"


# # Make and API request using the params dictionaty
# name_address = requests.get(base_url, params=params)

# # Convert the API response to JSON format
# name_address = name_address.json()
# print(name_address)

# # print(json.dumps(name_address, indent = 4))
# # Grab the first hotel from the results and store the name in the hotel_df DataFrame
# # try:
# #     hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
# # except (KeyError, IndexError):
# #     # If no hotel is found, set the hotel name as "No hotel found".
# #     hotel_df.loc[index, "Hotel Name"] = "No hotel found"

# # Log the search results
# # print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# # Display sample data
# hotel_df
# Out:
# Starting hotel search
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation",
    "conditions": "dogs.yes",
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    hotel_lat = row['Lat']
    hotel_lng = row['Lng']
    
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{hotel_lng},{hotel_lat},{radius}"
    params["bias"] = f"proximity:{hotel_lng}, {hotel_lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
print(name_address)
# Out:
# Starting hotel search
# hobart - nearest hotel: No hotel found
# new norfolk - nearest hotel: No hotel found
# chuncheng - nearest hotel: No hotel found
# the valley - nearest hotel: No hotel found
# nagothana - nearest hotel: No hotel found
# parakou - nearest hotel: No hotel found
# esperance - nearest hotel: No hotel found
# qandala - nearest hotel: No hotel found
# kahului - nearest hotel: No hotel found
# zabid - nearest hotel: No hotel found
# pedernales - nearest hotel: No hotel found
# faanui - nearest hotel: No hotel found
# wollongong - nearest hotel: No hotel found
# vinh - nearest hotel: No hotel found
# aden - nearest hotel: No hotel found
# villa bruzual - nearest hotel: No hotel found
# mount gambier - nearest hotel: No hotel found
# edd - nearest hotel: No hotel found
# fare - nearest hotel: No hotel found
# puerto rondon - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
